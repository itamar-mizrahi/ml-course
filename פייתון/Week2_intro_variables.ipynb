# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # New Section

# %% [markdown]
# <h1 dir='rtl'><b>שיעור #1 - משתנים , סוגי משתנים, פונקציית ()print, ואופרטורים</b></h1>
#
# <h1 dir='rtl'><u>מה נלמד</u></h1>
# <p dir='rtl'>* משתנים</p>
# <p dir='rtl'>* סוגי משתנים</p>
# <p dir='rtl'>* פקודת הדפסה</p>
# <p dir='rtl'>* אופרטורים</p>
#
# <h1 dir='rtl'><u>ללמוד לתכנת-טיפים כלליים</u></h1>
# <p dir='rtl'>* <b>הרבה</b> תרגול</p>
# <p dir='rtl'>* להשקיע זמן</p>
# <p dir='rtl'>*  !! לדייק בתחביר !!</p>
# <p dir='rtl'>*  !! לתעד את הקוד !!</p>
# <p dir='rtl'>* יהיו באגים, זה מתאגר אבל גם מספק כאשר מצליחים לפתור אותם</p>
#
# <h1 dir='rtl'><u>אתרים ללמוד עצמי</u></h1>
#
# * The Algorithm Design Manual by Steven S Skiena (highly recommended)
# * [Python Documentation](https://docs.python.org/2.7/)
# * [Think Python: How to Think Like a Computer Scientist](http://www.greenteapress.com/thinkpython/html/index.html) by Allen B. Downey
# * [Python Programming](http://en.wikibooks.org/wiki/Python_Programming) WikiBook
# * [The Python Tutorial](https://docs.python.org/2/tutorial/index.html) official tutorial

# %% [markdown]
# <h1 dir='rtl'><b>משתנים</b></h1>
# <h2 dir='rtl'><u>סוגי משתנים בפייתון</u></h2>
# <p dir='rtl'>ישנם סוגי משתנים שונים</p>
# <p dir='rtl'>לכל סוג משתנה מקצה המחשב מספר מסוים של ביטים בזיכרון בהתאם לגודל תבנית הביטים המייצגת את סוג המשתנה</p>
#
# ![image.png](data:image/png;base64,...)
# _________________
#
# <h2 dir='rtl'><u>בנק פונקציות</u></h2>
#
# > print()
#
# באמצעות הפונקציה הזו נוכל "להדפיס" (להציג על המסך) פלטים על המסך
# כדי להדפיס על המסך ערך כלשהו, נכתוב את המילה
#
# print(*הערך שנרצה להדפיס*)
#
# ניתן להדפיס מספרים, תווים, משפטים, מילים, משתנים
#
# > type()
#
# באמצעות הפונקציה הזו נוכל הציג על המסך את סוג המשתנה
# _________________

# %% [markdown]
# <h1 dir='rtl'><b>תרגול 1.1</b></h1>
# <h2 dir='rtl'><u>התנסות בהדפסה</u></h2>
#
# ![image.png](data:image/png;base64,...)

# %%
#YOUR CODE:
# Out:
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *

# %% [markdown]
# <h1 dir='rtl'><b>תרגול 1.2</b></h1>
# <h2 dir='rtl'><u>התנסות בהדפסה, ובפקודת מעבר שורה</u></h2>
# <h2 dir='ltr'>\n מעבר שורה</h2>
# <p dir='rtl'>שימו לב לשורות קוד הבאות: בין המילה hello והמילה world יש מעבר שורה</p>
#
# ![image.png](data:image/png;base64,...)
#
# <p dir='rtl'>ועכשיו תורכם: ציירו ריבוע, השתמשו במעבר שורה בכדי לצייר את 4 השורות של הכוכביות</p>
#
# ![image.png](data:image/png;base64,...)
#
# השתמשו ב
#
# \n
#
# למעבר שורה

# %%
#YOUR CODE:
# Out:
# * * * *
# * * * *
# * * * *
# * * * *

# %% [markdown]
# <h2 dir='rtl'><u>הדפסה ()print – מלל המורכב ממחרוזת ומהערך במשתנה</u></h2>

# %%
#YOUR CODE:
my_name = "???"
my_child = "???" # not a lie
my_height = "???"
my_eyes = "???"
print ("Let's talk about %s." % my_name)
print ("he's %d centimeters tall." % my_height)
print ("he's got %s eyes and has %i childrens." % (my_eyes, my_child))

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
pi=3.1415926535
print ("The value of Pi is: %.2f"  %  pi) #2 digits after dot
print ("The value of Pi is: %.4f"  %  pi) #4 digits after dot
# Out:
# The value of Pi is: 3.14
# The value of Pi is: 3.1416

# %%
# דרך נוספת להדפסה של מלל יחד עם ערכי משתנה
# https://docs.python.org/3/tutorial/inputoutput.html

cost = 3.222333
print(f'Cost at initial w is: {cost:.3f} dollars')

#ודרך נוספת...
print("Cost at initial w is:",cost,"dollars")

#ואפילו עוד אחת...
cost = "3.222333"
print("Cost at initial w is: "+ cost +" dollars")
# Out:
# Cost at initial w is: 3.222 dollars
# Cost at initial w is: 3.222333 dollars
# Cost at initial w is: 3.222333 dollars

# %% [markdown]
# <h1 dir='rtl'><b>תרגול 1.3</b></h1>
# <h2 dir='rtl'><u>התנסות בפונקציה ()type, סוגי משתנים</u></h2>
#
# <p dir='rtl'>1) הריצו את הקוד בבלוק הבא ורישמו מה סוג המשתנה a,b בכל שורת קוד</p>
# <p dir='rtl'>מחרוזת</p>
# <p dir='rtl'>מספר שלם</p>
# <p dir='rtl'>מספר עשרוני</p>
# <p dir='rtl'>בוליאני</p>

# %%
#סוגי משתנים
a="Hello world"
print(type(a))
#YOUR ANSWER IS: "???"
a=1.0
print(type(a))
#YOUR ANSWER IS: "???"
a=1
print(type(a))
#YOUR ANSWER IS: "???"
a=True
b=False
print("type of var a is: ", type(a),"\ntype of var b is: ",type(b))
#YOUR ANSWER IS: "???"
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# type of var a is:  <class 'bool'>
# type of var b is:  <class 'bool'>

# %%
#השמה ע"י הצבה
x = "ML"
print(x)

#השמה ע"י קלט מהמשתמש
x = input("מה ראשי תיבות של בינה מלאכותית")
print(x)
x = input("בן כמה אתה?")
print(x, type(x))
x = int(input("שוב בן כמה אתה?"))
print(x, type(x))
x = float(input("ופעם אחרונה בן כמה אתה?"))
print(x, type(x))

#עידכון משתנה עם ערך חדש
x = 2
x= x+ 2
print(x, type(x))

z = 12
z = z * z
print (z)
1
# Out:
# ML
# מה ראשי תיבות של בינה מלאכותית789
# 789
# בן כמה אתה?15
# 15 <class 'str'>
# שוב בן כמה אתה?15
# 15 <class 'int'>
# ופעם אחרונה בן כמה אתה?15
# 15.0 <class 'float'>
# 4 <class 'int'>
# 144
# 1

# %% [markdown]
# <p dir='rtl'>2) נסו לנחש את סוגי המשתנים בדוגמאות הבאות ואז בדקו את עצמכם </p>
#
# >type(17)
#
# >type('17')
#
# >type('3.2')
#
# >type(-1)
#
# >type(.000045)
#
# >type(1000000)
#
# >type(1,000,000)
#
# שימו לב
# ❤
# מה הטיפוס של
# 1,000,000

# %%
#YOUR CODE:

# %% [markdown]
# <h1 dir='rtl'><b>תרגיל 1.4 - מספרים עשרוניים</b></h1>
# <h2 dir='rtl'><u>צורת רישום נוספת - מספר עשרוני</u></h2>
# <p dir='rtl'>במדע ובהנדסה עובדים בטווח רחב של ערכים. בתחומי ידע אלו נהוג להשתמש בחזקות של עשר כאשר רוצים לכתוב מספרים עשרוניים גדולים מאוד או קטנים מאוד.</p>
# <p dir='rtl'>למשל - במקום לכתוב 2500000  נוכל לכתוב</p>
# <p dir='ltr'>25*10^5</p>
# <p dir='rtl'>בפייתון נכתוב</p>
# 25e5
# <p dir='rtl'>או</p>
# 2.5e26
# <p dir='rtl'>❓ איך ניתן לכתוב 0.0002 ❓</p>

# %%
#YOUR CODE:

# %% [markdown]
# <h1 dir='rtl'><b>אופרטורים</b></h1>
# <p dir='rtl'>ניתן להשתמש בחיבור, חיסור, כפל וחילוק כפי שרגילים.</p>
# <p dir='rtl'>חוקי סדר הפעולות הוא דומה למה שאתם בעצם מכירים (כפל וחילוק קודמים לחיבור וחיסור), ולכן יש צורך להגדיר בצורה נכונה את הפעולה הנדרשת ולהשתמש בסוגריים בשעת הצורך.</p>
#
#
# ![image.png](data:image/png;base64,...)
#
# <p dir='rtl'>מה תהיה תוצאת שארית החילוק של 12.4%3</p>
# <p dir='rtl'>מה התוצאה של 12.4 לחלק ל 3</p>
# <p dir='rtl'>מה המנה השלמה של 12.4 לחלק ל 3</p>
# <p dir='rtl'>❓נסו בעצמכם❓</p>

# %%
#YOUR CODE HERE
# Out:
# 0.40000000000000036
# 4.133333333333334
# 4.0

# %% [markdown]
# <h1 dir='rtl'><b>תרגול 1.5</b></h1>
# <h2 dir='rtl'><u>חשבו בעזרת פייתון את התרגילים הבאים וכתבו את התשובות שמתקבלות</u></h2>
#
# 11.0 / 4
#
# 11 / 4
#
#
# 11 % 4
#
#
# 11 / -4
#
#
# 2.0 + 1
#
#
# 12 * 2.5
#
#
# 0.03 - 0.029
#
#
# 0.01 - 0.009
#
#
# 0.01-0.009-0.0001

# %%
#YOUR CODE HERE
# Out:
# 2.75
# 2.75
# 3
# -2.75
# 3.0
# 30.0
# 0.0009999999999999974
# 0.0010000000000000009
# 0.0009000000000000008

# %% [markdown]
# <p dir='rtl'>שימו לב</p>
# <p dir='rtl'>❤</p>
# <p dir='rtl'>הסיבה שבדוגמאות האחרונות לא קיבלנו את התוצאות הרצויות נובעת מכך שהייצוג המספרי של תוצאת החיסור נשמר במחשב במספר רב יותר של ספרות מאשר מופיע בתשובה ולכן התוצאה מאוד קרובה אולם אינה המספר המדויק.</p>
#
# ---
#
# <h1 dir='rtl'>כל הכבוד</h1>
# <h2 dir='rtl'><u>מה למדנו?</u></h2>
# <p dir='rtl'>* הכרנו את סוגי המשתנים</p>
# <p dir='rtl'>* למדנו להדפיס על המסך</p>
# <p dir='rtl'>* למדנו סוגי אופרטורים</p>
#
# <h1 dir='rtl'>בונוס</h1>
# <p dir='rtl'>ניתן להגיש כבונוס את התרגיל בעמוד האחרון של המצגת</p>

# %%
#YOUR CODE HERE
# Out:
# the firstvar is : -0.3055
# the value of secondvar is : -0.30077006112902743
# the value of third var is : 0.09188525367491789
