# %% [markdown]
# #שם התלמיד/ה
#
# נא להוסיף את שמך
#
# ...............................
#
# ---

# %% [markdown]
# ## פונקציות

# %% [markdown]
# פתחו את הקישור הבא
#
# https://www.w3schools.com/python/python_functions.asp
#
# בצעו את הלימוד העצמי ופתרו את התרגילים הבאים:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#YOUR CODE 1.1

# %%
#YOUR CODE 1.2

# %%
#YOUR CODE 1.3

# %%
#YOUR CODE 1.4

# %% [markdown]
# פתחו את הקישור הבא:
#
# https://www.w3schools.com/python/python_lambda.asp
#
# בצעו את התרגילים הבאים:

# %% [markdown]
# calculate y1 = a * x + b
#
# calculate y2 = a * x - b
#
# שנה את בקוד את סימני השאלה (???) בכדי להגדיר את החישוב באופן נכון:
#
#
# y1 = lambda a, x, b : ???
#
#
# print(y1(5, 6, 2)) #32
#
#
# y2 = lambda a, x, b : ???
#
#
# print(y1(5, 6, 2)) #28

# %%
# YOUR CODE HERE 1.5

# %% [markdown]
# ## רשימות
#
# פתחו את הקישור הבא:
#
# https://www.w3schools.com/python/python_lists.asp

# %% [markdown]
# ## מילונים
# פתחו את הקישור הבא:
#
# https://www.w3schools.com/python/python_dictionaries.asp
#
# ופתרו את התרגילים הבאים:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#YOUR CODE HERE 2.1

# %%
#YOUR CODE HERE 2.2

# %%
#YOUR CODE HERE 2.3

# %% [markdown]
# ## random

# %%
import random
# הדפסת 10 מספרים בטווח שבין 10 עד 20
for i in range (10):
	print(random.randint(10,20))

# %%
import random
#בחירת שם מרשימה
names = ["Julina", "Mary", "Majd", "Gazal"]

raname = random.choice(names)

print(raname)

# %% [markdown]
# צור רשימה של 5 תלמידים, כולל השם שלך
#
# כתוב תוכנית שבוחרת שם בצורה רנדומלית מתוך הרשימה שהגדרת
#
#  התוכנית תבחר שם כל עוד השם ברשימה שנבחר שונה מהשם שלך
#
#
#  כתוב כפלט:
#
#  השם שלי הוא: ??? והוא נבחר אחרי ??? פעמים

# %%
#YOUR CODE HERE 3.1

# %% [markdown]
# Edited by: Merav Varsano, maala Davidson
