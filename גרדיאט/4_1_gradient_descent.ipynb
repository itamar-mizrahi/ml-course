# %% [markdown]
# שם התלמיד
#
#
# ............................

# %% [markdown]
# <h1 dir = rtl>
# מציאת מינימום של פונקציה בצורה חישובית
# <h1>
# <p dir = rtl>
# במימוש רשתות עמוקות נשתמש הרבה בטכניקה של מציאת מינימום לפונקציות מורכבות ומרובות משתנים
# <br>
# אין ביכולתינו למצוא את נקודות המינימום של הפונקציות האלו בשיטות אנליטיות כפי שאנחנו מכירים (גזירה, השוואה לאפס ומציאת המשתנה או המשתנים שהם נקודת המינימום) ולכן אנחנו צריכים להשתמש בשיטות חישוביות. למזלינו עומדים לרשותינו מחשבים חזקים היודעים לבצע פעולות אלו במהירות וביעילות
# <br>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import time

# %% [markdown]
# <p dir = rtl>
# נתחיל עם פונקציה פשוטה יחסית עם משתנה אחד בלבד:
# <br><br>
# $$f(x)=x^2-10x+5$$
# <br><br>
# </p>

# %% [markdown]
# <hr>
# <h2 dir = rtl>
# תרגיל 0
# </h2>
# <p dir = rtl>
# מצאו את נקודת המינימום של הפונקציה בשיטה אנליטית (דף ועט או עיפרון) שאתם מכירים ורישמו את התוצאה כאן<br><br>
# </p>

# %% [markdown]
# <hr>
# <h2 dir = rtl>
# תרגיל 1
# </h2>
# <p dir = rtl>
# ממשו את הפעולות <code>f(x)</code> ו- <code>df_dx(x)</code> המתאימות לפונקציה זו
# <br><br>
# </p>

# %%
# Add your code here

# %% [markdown]
# <p dir = rtl>
# שורות הקוד הבאות יציירו את הפונקציה $f(x)$ שמימשתם
# <br>
# שורות הקוד בונות את מערכי ציר ה x וציר ה y של הגרף בעזרת numpy והפונקציה שמימשתם ולאחר מכן מציגות את הפונקציה בגרף.
# <br>
# </p>

# %%
x = np.linspace(-5,15,1000)
y = f(x)
plt.figure(figsize = (10,6))
plt.plot(x , y)

# %% [markdown]
# <p dir = rtl>
# אם מימשתם נכון, תצויר פרבולה שנקודת המינימום שלה היא $(5.0,-20)$
# </p>

# %% [markdown]
# <hr>
# <h2 dir = rtl>
# תרגיל 2
# </h2>
# <p dir = rtl>
# בתרגיל זה נמצא מינימום של פונקציה בשיטת ה Gradient Descent
# <br><br>
# כתבו את הפעולה <code>find_min_gradient_descent</code> המקבלת את הפרמטרים הבאים:
# <ul dir = rtl>
# <li>
# dx - הפנייה  לפונקציית הנגזרת של הפונקציה שעבורה צריך למצוא את נקודת המינימום
# </li>
# <li>
# x_init - הערך ההתחלתי של x שבו הפעולה אמורה לחפש את נקודת המינימום
# </li>
# <li>
# epochs - מספר הפעמים שבו הפונקציה תפעיל את צעד ה Gradient Descent
# </li>
# <li>
# alpha - קצב הלמידה, מקדם ההכפלה בנגזרת בצעד ה Gradient Descent
# </li>
# </ul>
# </p>
# <br>
# <p dir = rtl>
# הפעולה תבצע את צעד ה Gradient Descent:
# <br><br>
# $$x = x - \alpha \frac{\partial f(x)}{\partial x}$$
# <br><br>
# epochs פעמים ובכל פעם תוסיף את ערך ה x החדש לרשימה
# <br>
# הפעולה תחזיר את הרשימה שנבנתה
# </p>

# %%
epochs = 40
alpha = 0.1

# %%
def find_min_gradient_descent(dx , x_init , epochs , alpha):
  history = [x_init]

  # Add your code here


  #End of your code

  return history

# %%
h = find_min_gradient_descent(df_dx , -5 , epochs , alpha)
print(h[-1] , f(h[-1]))

# %% [markdown]
# <p dir = rtl>
# התא הקודם מדפיס את ערך ה x  האחרון ברשימה שהוחזרה ואת ערך הפונקציה עבורו. אתם אמורים לקבל תוצאות דומות לאלה שהתקבלו בתרגילים הקודמים למעלה
# </p>

# %% [markdown]
# <p dir = rtl>
# שרטטו על אותה מערכת צירים את ערכי  X Y בכל 40 האיטרציות
# </p>

# %%
# Add your code here

# %% [markdown]
# <p dir = rtl>
# אם הקוד שלכם נכון יודפס על המסך הגרף הבא</p>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <hr>
# <p dir = rtl>
# נציג בצורה גרפית את התכנסות אלגוריתם ה gradient Descent, כלומר עד כמה מהר x מתייצב על ערך של נקודת המינימום של הפונקציה. נציג את הרשימה שהפעולה find_min_gradient_descent החזירה
# <br>
# מימוש נכון וקריאה לפונקציה עם epochos=40 ו- alpha=0.1 יראה את הגרף הבא:
# <br><br>
# </p>
# <img src = 'https://github.com/Oran-Uzrad/DataFiles/raw/master/Hamoshava/etc/GD1.JPG' alt = 'example' height = 380>

# %%
plt.figure(figsize = (10,6))
plt.yticks(np.arange(-5, 7, 1))
plt.plot(list(range(0 , epochs + 1)) , h , color = 'b')

# %% [markdown]
# <hr>
# <h2 dir = rtl>
# תרגיל 3
# </h2>
# <p dir = rtl>
# הריצו את הפונקציה 4 פעמים:
# </p>
# <ul dir = rtl>
# <li>
# עבור epochs=40 ו- alpha=0.01 - שימו את הרשימה שהפונקציה מחזירה במשתנה בשם h001
# </li>
# <li>
# עבור epochs=40 ו- alpha=0.03 - שימו את הרשימה שהפונקציה מחזירה במשתנה בשם h003
# </li>
# <li>
# עבור epochs=40 ו- alpha=0.1 - שימו את הרשימה שהפונקציה מחזירה במשתנה בשם h01
# </li>
# <li>
# עבור epochs=40 ו- alpha=0.3 - שימו את הרשימה שהפונקציה מחזירה במשתנה בשם h03
# </li>
# </ul>
# <p dir = rtl>
# הריצו את התא הבא היוצר גרף המשלב את ארבעת תוצאות ההרצות של הפונקציה.
# <br>
# אתם אמורים לקבל את הגרף הבא. התבוננו בגרף ונסו להסביר את ההבדלים בין קווי ההתכנסות השונים
# </p>
# <br><br>
# <img src = 'https://github.com/Oran-Uzrad/DataFiles/raw/master/Hamoshava/etc/GD2.JPG' alt = 'example' height = 380>

# %%
h001 = # Add your code here
h003 = # Add your code here
h01 = # Add your code here
h03 = # Add your code here

# %%
plt.figure(figsize = (10,6))
plt.yticks(np.arange(-5, 7, 1))
plt.plot(list(range(0 , epochs + 1)) , h001 , color = 'b')
plt.plot(list(range(0 , epochs + 1)) , h003 , color = 'g')
plt.plot(list(range(0 , epochs + 1)) , h01 , color = 'r')
plt.plot(list(range(0 , epochs + 1)) , h03 , color = 'c')
plt.legend(['alpha = 0.01' , 'alpha = 0.03' , 'Aalpha = 0.1' , 'alpha = 0.3'])

# %% [markdown]
# <hr>
# <h2 dir = rtl>
# תרגיל 4
# </h2>
# <p dir = rtl>
# הריצו את הפונקציה פעם נוספת:
# </p>
# <ul dir = rtl>
# <li>
# עבור epochs=40 ו- alpha=1.1 - שימו את הרשימה שהפונקציה מחזירה במשתנה בשם h11
# </li>
# </ul>
# <p dir = rtl>
# הריצו את התא הבא היוצר גרף המתאר את תוצאת ההרצה.
# <br>
# אתם אמורים לקבל את הגרף הבא. התבוננו בגרף ונסו להסביר מה קרה הפעם
# </p>
# <br><br>
# <img src = 'https://github.com/Oran-Uzrad/DataFiles/raw/master/Hamoshava/etc/GD3.JPG' alt = 'example' height = 380>

# %%
h11 = # Add your code here

# %%
plt.figure(figsize = (10,6))
plt.yticks(np.arange(-16000, 14000 , 2000))
plt.plot(list(range(0 , epochs + 1)) , h11 , color = 'm')
plt.legend(['alpha = 1.1'])

# %% [markdown]
# <h3 dir = rtl>
#
# <font color = 'green'>
# ברכותי! אם הגעתם הנה, הפעלתם (גם אם בצורה פשוטה) את אלגוריתם ה Gradient Descent שעומד בבסיס ה Deep Learning
# </font>
# </h3>
