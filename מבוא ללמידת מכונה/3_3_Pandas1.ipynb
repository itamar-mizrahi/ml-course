# %% [markdown]
# שם התלמיד
#
# ......................

# %% [markdown]
# <div dir=rtl>
# <H1><B>PANDAS</B></H1>
# <H2><B>מחברת ללימוד עצמי ותרגול</B></H2>
#
# השלימו את הקוד בתיבות הקוד שבהם רשום:
#
# YOUR CODE HERE

# %% [markdown]
# <div dir=rtl>
# <H1>ייבוא הספריה לסביבת העבודה</H1>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <div dir=rtl>
# <H1>ניתן ליצור נתונים בטבלה בכמה שיטות</H1>
#
# *   שיטה 1 - יצירת נתונים בעמודות - שילוב העמודות לטבלה
# *   שיטה 2 - טעינת נתונים מקובץ
# *   שיטה 3 - יצירת טבלה מתוך מטריצה

# %% [markdown]
# <div dir=rtl>
# <H1>שיטה 1</H>
# <H3>טעינת נתונים מתוך עמודות</H3>

# %%
# שיטה 1
# יצירת טבלה מתוך מילון
df00 = pd.DataFrame({
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]})
print(df00)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
# יצירת טבלה מתוך מילון
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df01 = pd.DataFrame(data)

print(df01)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#יצירת טבלה מתוך סדרות
calories=pd.Series([420,380,390])
duration=pd.Series([50,40,45])
df02=pd.DataFrame({"calories1":calories,"duration1":duration})
print(df02)
# Out:
#    calories1  duration1
# 0        420         50
# 1        380         40
# 2        390         45

# %% [markdown]
# <div dir=rtl>
# <H1>שיטה 2</H1>
# <H2>טעינת קובץ - אופציה 1 - הקובץ שמור מקומית</H2>

# %%
# העלאת הקובץ:
# Iris_Data.csv
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c4fd2c1e-d46f-447e-9f4e-c9d890a20280" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4fd2c1e-d46f-447e-9f4e-c9d890a20280">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded['Iris_Data.csv']))
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# <div dir=rtl>
# <H3>
# טעינת קובץ - אופציה 2 - קובץ שמור בדרייב
# </H3>

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/iris_flowers.csv')
print(df2)
# Out:
#      sepal_length  sepal_width  petal_length   petal_width           class
# 0             5.1          3.5           1.4           0.2     iris_setosa
# 1             4.9          3.0           1.4           0.2     iris_setosa
# 2             4.7          3.2           1.3           0.2     iris_setosa
# 3             4.6          3.1           1.5           0.2     iris_setosa
# 4             5.0          3.6           1.4           0.2     iris_setosa
# ..            ...          ...           ...           ...             ...
# 145           6.7          3.0           5.2           2.3  iris_virginica
# 146           6.3          2.5           5.0           1.9  iris_virginica
# 147           6.5          3.0           5.2           2.0  iris_virginica
# 148           6.2          3.4           5.4           2.3  iris_virginica
# 149           5.9          3.0           5.1           1.8  iris_virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# <div dir=rtl>
# <H1>שיטה 3</H1>
# <H2>יצירת טבלה מתוך מטריצה</H2>

# %%
#יצירת מטריצה עם מספרים בערכים רנדומליים, הערך הנמוך ביותר מינוס 20 הערך הגבוה ביותר 20
#למטריצה 5 שורות ו-4 עמודות
np.random.seed(42)
data1 = np.random.randint(-20,20,(5,4))
data1
# Out:
# array([[ 18,   8,  -6, -13],
#        [  0,  18,  -2,   2],
#        [-10, -10,   3,  15],
#        [ 19,   3, -18,   1],
#        [-19,   3,   9,  17]])

# %%
columns1 = ['A','B','C','D']
index1 = ['a','b','c','d','e']
df3 = pd.DataFrame(data=data1, index=index1, columns=columns1)
df3
# Out:
#     A   B   C   D
# a  18   8  -6 -13
# b   0  18  -2   2
# c -10 -10   3  15
# d  19   3 -18   1
# e -19   3   9  17

# %% [markdown]
# <div dir=rtl>
# <H3>
# הצגת ראש הטבלה
# </H3>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %% [markdown]
# <div dir=rtl>
# <H3>
# הצגת סוף הטבלה
# </H3>

# %%
df.tail(2)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %% [markdown]
# <div dir=rtl>
# <H3>
# הצגת שמות העמודות
# </H3>

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# <div dir=rtl>
# <H3>
# הצגת עמודה/ת מסוים/ות מבין כל העמודות
# </H3>

# %%
df ['sepal_length'] # df[col] התוצאה היא רשימה
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df [['sepal_length']] # df[[col]] התוצאה היא טבלה
# Out:
#      sepal_length
# 0             5.1
# 1             4.9
# 2             4.7
# 3             4.6
# 4             5.0
# ..            ...
# 145           6.7
# 146           6.3
# 147           6.5
# 148           6.2
# 149           5.9
#
# [150 rows x 1 columns]

# %%
df [['sepal_length','sepal_width']] # באותו האופן ניתן לבחור מספר עמודות באמצעות הפרדה בפסיק בין שמות העמודות
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %% [markdown]
# <div dir=rtl>
# <H3>
# הצגת שורות מסוימות
# </H3>

# %%
df[10:12] #עפי אינדקס מספר השורה. אינדקס השורה הראשונה - 0
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa

# %%
df[df['species']=='Iris-setosa'] #בחירת שורות באמצעות תנאי
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
df[df['sepal_length']>6] #בחירת שורות באמצעות תנאי
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# 56            6.3          3.3           4.7          1.6  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 144           6.7          3.3           5.7          2.5   Iris-virginica
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 148           6.2          3.4           5.4          2.3   Iris-virginica
#
# [61 rows x 5 columns]

# %%
df[(df['sepal_length']>6) & (df['species']=='Iris-virginica')] #בחירת שורות באמצעות תנאי מורכב
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 107           7.3          2.9           6.3          1.8  Iris-virginica
# 108           6.7          2.5           5.8          1.8  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 110           6.5          3.2           5.1          2.0  Iris-virginica
# 111           6.4          2.7           5.3          1.9  Iris-virginica
# 112           6.8          3.0           5.5          2.1  Iris-virginica
# 115           6.4          3.2           5.3          2.3  Iris-virginica
# ...

# %%
df3=df[(df['sepal_length']>6) & (df['species']=='Iris-virginica')] #הגדרת טבלה חדשה שמכילה חלק מהשורות של טבלה מקורית באמצעות תנאי מורכב
print(df3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 107           7.3          2.9           6.3          1.8  Iris-virginica
# 108           6.7          2.5           5.8          1.8  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 110           6.5          3.2           5.1          2.0  Iris-virginica
# 111           6.4          2.7           5.3          1.9  Iris-virginica
# 112           6.8          3.0           5.5          2.1  Iris-virginica
# 115           6.4          3.2           5.3          2.3  Iris-virginica
# ...

# %% [markdown]
# <div dir=rtl>
# <H3>
# אינפורמציה חשובה של הטבלה
# </H3>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# <div dir=rtl>
# <H3>
# סטטיסטיקה תיאורית
# </H3>

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# <div dir=rtl>
# <H1>תרגיל 1</H1>
# <H2>בצעו והציגו את החיתוכים הבאים:
#
# **  כל הפרחים מסוג virginica
#
# **  כל הפרחים שאינם מסוג virginica
#
# **  20 הפרחים הראשונים
#
# **  20 הפרחים הראשונים לאחר ערבול הטבלה
#
# **  כל הפרחים עם sepal length מעל 6.0
#
# **  הערה: יש להתאים את שמות העמודות ושמות הפרחים לטבלה שברשותכםן
#
# </H2>

# %%
# YOUR CODE HERE

# %% [markdown]
# <div dir=rtl>
# <H3> הוספת עמודה נוספת לטבלה
#
# העמודה הנוספת הינה חיבור איברי עמודה A ועמודה B ועוד 1
# </H3>

# %%
df3['E']=df3['A']+df3['B']+1
df3
# Out:
#     A   B   C   D   E
# a  18   8  -6 -13  27
# b   0  18  -2   2  19
# c -10 -10   3  15 -19
# d  19   3 -18   1  23
# e -19   3   9  17 -15

# %% [markdown]
# <div dir=rtl>
# <H3> מחיקת עמודה מטבלה
# </H3>

# %%
df3 = df3.drop('E',axis=1)
df3
# Out:
#     A   B   C   D
# a  18   8  -6 -13
# b   0  18  -2   2
# c -10 -10   3  15
# d  19   3 -18   1
# e -19   3   9  17

# %% [markdown]
# <div dir=rtl>
# <H1>תרגיל 2</H1>
# <H2>מחקו את שורות a  ו c מטבלה df3
# </H2>

# %%
# YOUR CODE HERE
# Out:
#     A   B   C   D
# b   0  18  -2   2
# d  19   3 -18   1
# e -19   3   9  17

# %% [markdown]
# <div dir=rtl>
# <H1>
# מחיקת ערכים חסרים
# </H1>

# %%
df4 = pd.DataFrame({'A':[1,2,np.nan,4],
                  'B':[5,np.nan,np.nan,8],
                  'C':[9,10,11,12]})
df4
# Out:
#      A    B   C
# 0  1.0  5.0   9
# 1  2.0  NaN  10
# 2  NaN  NaN  11
# 3  4.0  8.0  12

# %% [markdown]
# <div dir=rtl><H3>
# מחיקת עמודות עם ערכים חסרים
# </H3>

# %%
df4 = df4.dropna(axis=1)
df4
# Out:
#     C
# 0   9
# 1  10
# 2  11
# 3  12

# %% [markdown]
# <div dir=rtl><H3>
# מחיקת שורות עם ערכים חסרים
# </H3>

# %%
df4 = pd.DataFrame({'A':[1,2,np.nan,4],
                  'B':[5,np.nan,np.nan,8],
                  'C':[9,10,11,12]})
df4
# Out:
#      A    B   C
# 0  1.0  5.0   9
# 1  2.0  NaN  10
# 2  NaN  NaN  11
# 3  4.0  8.0  12

# %%
df4 = df4.dropna(axis=0)
df4
# Out:
#      A    B   C
# 0  1.0  5.0   9
# 3  4.0  8.0  12

# %% [markdown]
# נערך ע"י מרב ורסנו
# מכון דוידסון
