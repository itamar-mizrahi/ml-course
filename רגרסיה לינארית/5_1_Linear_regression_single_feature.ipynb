# %% [markdown]
# # שם התלמיד
#
# ............................

# %% [markdown]
# <h1 dir = rtl>
# <b>
# רגרסיה לינארית, משתנה בודד
# </b>
# <p dir = rtl>
# במחברת כאן נממש את תהליך הלמידה של מודל הרגרסיה הלינארית עם משתנה בודד, כלומר עם משתנה בלתי תלוי אחד
# </p>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Iris data

# %%
df = sns.load_dataset('iris')

# %%
print (df.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
X=df['petal_length'].to_numpy()
y=df['petal_width'].to_numpy()
print(X.shape, y.shape)
# Out:
# (150,) (150,)

# %% [markdown]
# <p dir = rtl>
# <br>הצגה ויזואלית של התלות בין המאפיין petal_length ל  petal_width  <br>
# </p>

# %%
g = sns.relplot(x='petal_length', y='petal_width', data=df, hue='species', style='species')
# To set the title
g.fig.suptitle('petal_length Vs. petal_width', fontsize=16)
# To adjust the position of the title if needed
g.fig.subplots_adjust(top=0.9) # This might be necessary if the title overlaps with the plot
# Show the plot
plt.show()

# %% [markdown]
# <p dir = rtl><h1><b>שלב 1</b></h1></p>
# <p dir = rtl>מציאת הרגסיה הלינארית בעזרת Gradient Descent </p>
# <p dir = rtl><U> תרגיל 1</u></p>
# <p dir = rtl>ממשו את פונקציית העלות J ואת נגזרותיה לפי w ולפי b</p>
# <p dir = rtl>ממשו את הפונקציה לחישוב R2</p>
# <p dir = rtl>הפונקתיה מקבלת שני פרמטרים:</p>
# def r_squared(y_true, y_pred):
# <p dir = rtl>הפונקתיה מחזירה פרמטר אחד:</p>
# return r2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Functions

# %%
def J(w,b,X,y):
  # YOUR CODE HERE

# %%
def dw_(w,b,X,y):
  # YOUR CODE HERE

# %%
def db_(w,b,X,y):
  # YOUR CODE HERE

# %%
def r_squared(y_true, y_pred):
  # YOUR CODE HERE

# %% [markdown]
# <p h2 dir = rtl><b><u>תרגיל 2</h2></b></u></p>
# <p dir = rtl>כיתבו פונקציה שמוצאת את מקדמי ההתאמה הלינארית
# - w ו b</p>
# <p dir = rtl>כותרת הפונקציה:</p>
# <p dir = rtl>def fit(epochs,alpha):</p>
# <p dir = rtl>בתחילת הפונקציה אתחל את w ו b לאפס</p>
# <p dir = rtl>אתחלו שלוש רשימות ריקות</p>
# <p dir = rtl>בתוך לולאה בכל איטרציה : </p>
# <p dir = rtl>חישבו את ערך הטעות J </p>
# <p dir = rtl>הוסיפו לרשימה אחת את הערך של הטעות באיטרציה </p>
# <p dir = rtl>הוסיפו לרשימה שניה את הערך של w באיטרציה </p>
# <p dir = rtl>הוסיפו לרשימה שלישית את הערך של b באיטרציה </p>
# <p dir = rtl>בכל 10 איטראציות הדפיסו למסך:</p>
# <p dir = rtl>print(f"cost: {j}")</p>
# <p dir = rtl>עדכנו את הערך של w ע"י הפחתה מהערך של w את הנגזרת החלקית כפול גודל הצעד</p>
# <p dir = rtl>עדכנו את הערך של b ע"י הפחתה מהערך של b את הנגזרת החלקית כפול גודל הצעד</p>
# <p dir = rtl>הפונקציה מחזירה את ערכי w,b ושלושת הרשימות</p>

# %%
def fit(epochs,alpha):
  # YOUR CODE HERE
  return w,b,listj,listw,listb

# %% [markdown]
# <p h2 dir = rtl><b><u>תרגיל 2 - בדיקה</h2></b></u></p>
# <p dir = rtl>בידקו את הפונקציה כאשר גודל הצעד הוא 0.01, ומספר האיטראציות הוא 800</p>

# %%
alpha = 0.01
epochs = 800
w,b,listj,listw,listb = fit(epochs,alpha)
print(w)
print(b)
# Out:
# cost: 2.0155333333333334
# cost: 0.061585769896811866
# cost: 0.05333032692477399
# cost: 0.04856657009057891
# cost: 0.045817671060907755
# cost: 0.04423143437034339
# cost: 0.043316105429071376
# cost: 0.042787920022874494
# cost: 0.04248313361141055
# cost: 0.04230725833064137
# 0.40963880195296093
# -0.33533015186708937

# %% [markdown]
# <p h2 dir = rtl><b><u>תרגיל 2 - ויזואליזציה של תוצאות ההרצה</h2></b></u></p>
# <p dir = rtl>שרטטו את גרף שבו מוצגים הנתונים כנקודות ועל אותה מערכת צירים הציגו את קו המגמה לאחר 10 איטרציות  </p>
# <p dir = rtl>הציגו את קו המגמה לאחר 100 איטרציות </p>
# <p dir = rtl>הציגו את קו המגמה לאחר 500 איטרציות </p>
# <p dir = rtl>הציגו את קו המגמה לאחר 800 איטרציות </p>

# %%
sns.scatterplot(x=X,y=y)
# לאחר 800 איטראציות
r = np.array([[X.min()],[X.max()]])
r_pred = r*w+b
plt.title("Regression line")
plt.plot(r,r_pred,color='red');

# YOUR CODE HERE
# לאחר 10 איטראציות

# YOUR CODE HERE
# לאחר 100 איטראציות

# YOUR CODE HERE
# לאחר 500 איטראציות

# %% [markdown]
# <p h2 dir = rtl><b><u>תרגיל 2 - ויזואליזציה של תוצאות ההרצה</h2></b></u></p>
# <p dir = rtl>שרטטו את גרף שבו מוצגים ערכי הטעות כתלות במספר האיטראציות</p>

# %%
# YOUR CODE HERE

# %% [markdown]
# <p h2 dir = rtl><b><u>תרגיל 2 - ויזואליזציה של תוצאות ההרצה</h2></b></u></p>
# <p dir = rtl>שרטטו את גרף שבו מוצגים ערכי w כתלות במספר האיטראציות</p>

# %%
# YOUR CODE HERE

# %% [markdown]
# <p h2 dir = rtl><b><u>תרגיל 2 - ויזואליזציה של תוצאות ההרצה</h2></b></u></p>
# <p dir = rtl>שרטטו את גרף שבו מוצגים ערכי b כתלות במספר האיטראציות</p>

# %%
# YOUR CODE HERE

# %% [markdown]
# <h1 dir = rtl>
# <b>
# שלב 2
# </b>
# <p dir = rtl>
# <br>מציאת הרגסיה הלינארית בעזרת SKLearn <br>
# </p>

# %% [markdown]
# # Linear regression with SKLearn

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
X1 = np.expand_dims(X,axis=1)
X1.shape
# Out:
# (150, 1)

# %%
reg = LinearRegression()
reg.fit(X1,y)
w_sk = reg.coef_
b_sk = reg.intercept_
print(w_sk,b_sk)
# Out:
# [0.41575542] -0.3630755213190291

# %%
sns.scatterplot(x=X, y=y)
r = np.array([[X.min()], [X.max()]])
r_pred = reg.predict(r)
plt.plot(r, r_pred, color='red')
plt.title("Scatterplot with Regression Line")
plt.xlabel("petal_length")
plt.ylabel("petal_width")
plt.show()

# %% [markdown]
# <p h2 dir = rtl><b><u>תרגיל 3 - השוואה בין התוצאות: רגרסיה לינארית </h2></b></u></p>
# <p dir = rtl>שרטטו על אותה מערכת הצירים את שני קווי המגמה</p>
# <p dir = rtl>השוו את ערכי R2 של שני האלגוריתם</p>
# <p dir = rtl>איזה קו מגמה משקף טוב יותר את ההתאמה?</p>

# %%
# YOUR CODE HERE
# Plot to regression lines

# %%
# YOUR CODE HERE
# R2 - sklearn
# Out:
# 0.9271098389904927

# %%
# YOUR CODE HERE
# R2 - GD
# Out:
# 0.9268699266602675

# %% [markdown]
# # By: Merav Varsano - MAALA (מתוך השתלמות מורים)
