# %% [markdown]
# שם התלמיד
#
# .........................

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#YOUR CODE HERE
#imports libraries

# %%
#YOUR CODE HERE
# Create the x values from -10 to 10, in a 1 step

# %%
# Define logsig,tansig functions in Python
def logsig(x):
    return 1 / (1 + np.exp(-x))

def tansig(x):
    return 2 / (1 + np.exp(-2*x)) - 1

# %%
# Calculate the function values
z1 = logsig(x)
z2 = np.heaviside(x, 0.5)  # Heaviside step function, 0.5 at x=0
z3 = tansig(x)
z4 = np.sign(x)  # Sign function

# %%
#YOUR CODE HERE

# Plot the 4 functions


# logsig plot


# heaviside plot


# tansig plot


# sign plot


# Show the plots
